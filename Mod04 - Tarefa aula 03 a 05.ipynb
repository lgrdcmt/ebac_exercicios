# %% [markdown]
# # Tarefa 02
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os tutores
# - Divirta-se :)
#
# ## Exercício 1: Vestibular
#
# Considere que a os dados gerados na célula abaixo contêm o número de acertos de 100 alunos em um vestibular para um curso de exatas, divididas pelos respectivos assuntos. Considere que cada assunto possui um número de questões conforme a tabela abaixo:
#
# | assunto | número de questões |
# |:---:|:---:|
# | Matemática | 24 |
# | Português | 18 |
# | Geografia | 8 |
# | Inglês | 8 |
# | História | 8 |
# | Física | 12 |
# | Química | 12 |
#
# Usando os comandos de operações com DataFrames que você aprendeu na Aula 03, calcule:
#
# 1. (operações com escalar) Calcule o percentual de acerto dos alunos por assunto.
# 2. (operações entre *DataFrames) Calcule o total de acertos de cada aluno.
# 3. Calcule o porcentual geral de cada aluno.
# 4. Suponha que a nota de corte para a segunda fase seja 45. Quantos alunos tiveram nota maior que 45?

# %%
import pandas as pd
import numpy as np

np.random.seed(42)
df_mat = pd.DataFrame(np.random.randint(24, size=(100, 1)), columns=['Qt_acertos'])

df_por = pd.DataFrame(np.random.randint(18, size=(100, 1)), columns=['Qt_acertos'])

df_geo = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_ing = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_his = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_fis = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

df_qui = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

# %%
# 1) Seu código aqui
print(f'Matemática: {(df_mat["Qt_acertos"].sum() / (24 * 100)):.2%}')
print(f'Português: {(df_por["Qt_acertos"].sum() / (18 * 100)):.2%}')
print(f'Geografia: {(df_geo["Qt_acertos"].sum() / (8 * 100)):.2%}')
print(f'Inglês: {(df_ing["Qt_acertos"].sum() / (8 * 100)):.2%}')
print(f'História: {(df_his["Qt_acertos"].sum() / (8 * 100)):.2%}')
print(f'Física: {(df_fis["Qt_acertos"].sum() / (12 * 100)):.2%}')
print(f'Química: {(df_qui["Qt_acertos"].sum() / (12 * 100)):.2%}')
# Out:
# Matemática: 49.38%
# Português: 40.17%
# Geografia: 42.00%
# Inglês: 47.62%
# História: 45.00%
# Física: 44.33%
# Química: 45.25%

# %%
# 2) Seu código aqui
df = pd.DataFrame()
df['Matemática'] = df_mat["Qt_acertos"]
df['Português'] = df_por["Qt_acertos"]
df['Geografia'] = df_geo["Qt_acertos"]
df['Inglês'] = df_ing["Qt_acertos"]
df['História'] = df_his["Qt_acertos"]
df['Física'] = df_fis["Qt_acertos"]
df['Química'] = df_qui["Qt_acertos"]
df['Total_Acertos'] = (df['Matemática'] + df['Português'] + 
                       df['Geografia'] + df['Inglês'] + 
                       df['História'] + df['Física'] + 
                       df['Química'])
df.head(10)
# Out:
#    Matemática  Português  Geografia  Inglês  História  Física  Química  \
# 0           6          7          7       3         1       8        3
# 1          19         10          0       0         0      11        8
# 2          14         16          0       5         7       4        4
# 3          10          7          3       4         0       0        8
# 4           7          2          2       7         0       9        3
# 5          20          2          5       3         2       9        9
# 6           6          0          7       7         5       0        4
# 7          18          4          4       7         7       1        8
# 8          22          9          2       7         6       5        7
# 9          10          6          3       6         4       8        2
#
#    Total_Acertos
# 0             35
# 1             48
# 2             50
# 3             32
# 4             30
# 5             50
# 6             29
# 7             49
# 8             58
# ...

# %%
# 3) Seu código aqui
Qt_acertos_total = 24 + 18 + 8 + 8 + 8 + 12 + 12

df['Total_Acertos_%'] = round((df['Total_Acertos'] / 90 * 100), 2)
df.head(10)
# Out:
#    Matemática  Português  Geografia  Inglês  História  Física  Química  \
# 0           6          7          7       3         1       8        3
# 1          19         10          0       0         0      11        8
# 2          14         16          0       5         7       4        4
# 3          10          7          3       4         0       0        8
# 4           7          2          2       7         0       9        3
# 5          20          2          5       3         2       9        9
# 6           6          0          7       7         5       0        4
# 7          18          4          4       7         7       1        8
# 8          22          9          2       7         6       5        7
# 9          10          6          3       6         4       8        2
#
#    Total_Acertos  Total_Acertos_%
# 0             35            38.89
# 1             48            53.33
# 2             50            55.56
# 3             32            35.56
# ...

# %%
# 4) Seu código aqui
df[df['Total_Acertos'] > 45].index.nunique()
# Out:
# 31

# %% [markdown]
# ## 2) Vestibular II
#
# Ainda sobre o mesmo banco de dados:
#
# 1. Neste vestibular, quem 'zera' em matemática, física ou química está desqualificado. Monte um novo *DataFrame* com os alunos desqualificados por este critério.
# 2. Quantos são esses alunos?
# 3. Qual a média desses alunos em história e geografia?
# 4. Monte um *DataFrame* com os alunos que passaram para a segunda fase. Repare que estes alunos não podem ter sido desqualificados.

# %%
# 1. Neste vestibular, quem 'zera' em matemática, física ou química está desqualificado. 
#    Monte um novo DataFrame com os alunos desqualificados por este critério.
#df_copy = df.copy()
#
#df_copy['Desqualificado'] = 0
#
#df_copy.loc[df_copy['Matemática'] == 0, 'Desqualificado'] = 1
#df_copy.loc[df_copy['Física'] == 0, 'Desqualificado'] = 1
#df_copy.loc[df_copy['Química'] == 0, 'Desqualificado'] = 1
#
df_desqualificados = df[ (df['Matemática'] == 0) |
                         (df['Física'] == 0) |
                         (df['Química'] == 0) ]

df_desqualificados.head(5)
# Out:
#     Matemática  Português  Geografia  Inglês  História  Física  Química  \
# 3           10          7          3       4         0       0        8
# 6            6          0          7       7         5       0        4
# 10          10          8          3       2         1       7        0
# 12          20          8          3       7         1       0        3
# 14           7         11          1       7         1       4        0
#
#     Total_Acertos  Total_Acertos_%
# 3              32            35.56
# 6              29            32.22
# 10             31            34.44
# 12             42            46.67
# 14             31            34.44

# %%
# 2. Quantos são esses alunos?
df_desqualificados.index.nunique()
# Out:
# 23

# %%
# 3. Qual a média desses alunos em história e geografia?
print(f'Média História: {df_desqualificados["História"].mean():.2}')
print(f'Média Geografia: {df_desqualificados["Geografia"].mean():.2}')
# Out:
# Média História: 3.4
# Média Geografia: 3.2

# %%
# 4. Monte um *DataFrame* com os alunos que passaram para a segunda fase. Repare que estes alunos não podem ter sido desqualificados.
#df_qualificados = df_copy[df_copy['Desqualificado'] == 0].copy()
#df_qualificados.head(5)

df_qualificados = df[ (df['Matemática'] != 0) &
                         (df['Física'] != 0) &
                         (df['Química'] != 0) ]
df_qualificados
# Out:
#     Matemática  Português  Geografia  Inglês  História  Física  Química  \
# 0            6          7          7       3         1       8        3
# 1           19         10          0       0         0      11        8
# 2           14         16          0       5         7       4        4
# 4            7          2          2       7         0       9        3
# 5           20          2          5       3         2       9        9
# ..         ...        ...        ...     ...       ...     ...      ...
# 93          12         16          5       5         6       6        6
# 95           6          4          7       1         4       9        3
# 96           8          1          4       6         1       4        3
# 97          23          5          0       2         4       1        5
# 99          11         15          0       1         6       7        2
#
#     Total_Acertos  Total_Acertos_%
# 0              35            38.89
# ...

# %% [markdown]
# ## 3) Vacinações no Acre
# Vamos trabalhar agora com a base de vacinações no Acre. Para facilitar a sua vida, copiamos o link do arquivo na célula abaixo.
#
# 1. Quantas vacinas estão registradas nessa base?
# 2. Quantos pacientes foram vacinados? (considere um paciente para cada valor único de ```paciente_id```)
# 3. Quantos pacientes únicos tomaram a primeira dose? OBS: Há um caractere especial neste campo. Receba os valores do campo com o método ```.unique()```.
# 4. Quantos pacientes com menos de 18 anos foram vacinados?
# 5. Quantos estabelecimentos aplicaram vacina no Acre?

# %%
### O arquivo disponibilizado está offline
#arquivo = 'https://s3-sa-east-1.amazonaws.com/ckan.saude.gov.br/PNI/vacina/uf/2021-05-23/uf%3DAC/part-00000-63e5bee2-3684-4286-b709-7fe85483b04e.c000.csv'
#Acredito que seja esse mesmo arquivo, porém mais atualizado
#arquivo = 'https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/SIPNI/COVID/uf/uf%3DAC/part-00000-d8bd2ba1-1bd9-41a3-b9e4-79e2108f87e1.c000.csv'

#arquivo = './registros de vacinacao covid ACRE.csv'
#Esse link até hoje (30/04/2022), está funcionando
arquivo = 'https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/SIPNI/COVID/uf/uf%3DAC/part-00000-7d05709a-1317-46c5-b532-3abe58cd4347.c000.csv'

# %%
# 1) Sua solução aqui

#Usei low_memory=False aqui, pois tinha bastante memória sobrando rsrs
vacAcre = pd.read_csv(arquivo, sep=';', low_memory=False)
vacAcre.head(5)
# Out:
#                                  document_id  \
# 0  4e15de2c-8226-4208-a510-a49398d202e9-i0b0
# 1  303fbfd3-1ba0-4a84-be24-def7bad001cf-i0b0
# 2  3d829033-85bf-4e13-8b28-829702ed21a2-i0b0
# 3  30eb23e8-b6f1-49ff-8c0a-009ae8ca0f73-i0b0
# 4  d2940168-c8e5-46d7-80fe-0ffd6bcc685d-i0b0
#
#                                          paciente_id  paciente_idade  \
# 0  1cdfdf4bc68e515dcc74fe99bcbc7ee26eef857164df11...              15
# 1  a4745f3673f3137bf557317216e6740ab64c94cd9b4c58...              21
# 2  c3ca47d5e936dc2bc00015b7defe86d995d2a67c8d0e23...              34
# 3  ab032b6adc389b3f72849b3ce3ab71bd193558ca078ed4...              17
# 4  f17a285f80984130d1b28847066ab45aa443264cacbe78...              52
#
#   paciente_dataNascimento paciente_enumSexoBiologico  paciente_racaCor_codigo  \
# 0              2006-06-22                          F                       99
# 1              2000-01-11                          M                        4
# ...

# %%
#vacAcre.index.nunique()
print(len(vacAcre))

#outra forma
print(vacAcre.shape[0])
# Out:
# 463960
# 463960

# %%
# 2) 
vacAcre['paciente_id'].nunique()
# Out:
# 370483

# %%
# 3) 
vacAcre.loc[vacAcre['vacina_descricao_dose'] == '1ª Dose', 'paciente_id'].nunique()
# Out:
# 216407

# %%
# 3) solução alternativa
vacAcre_1dose = vacAcre[vacAcre['vacina_descricao_dose'] == '1ª Dose'].copy()
vacAcre_1dose['paciente_id'].nunique()
# Out:
# 216407

# %%
# 4) 
vacAcre.loc[vacAcre['paciente_idade'] < 18, 'paciente_id'].nunique()
# Out:
# 58732

# %%
# 5)
vacAcre['estalecimento_noFantasia'].nunique()
# Out:
# 132

# %% [markdown]
# ## 4) Vacinação II
# Gere um *DataFrame* que contenha somente os estabelecimentos que aplicaram vcinas a menores de 18 anos. Nesse *DataFrame* devem conter somente os dados dos estabelecimentos, mais uma coluna sendo a quantidade de vacinas que o estabelecimento aplicou a menores de 18 anos.
#
# 1. crie uma cópia do *DataFrame* original, contendo somente os registros de vacinas realizadas a menores de 18 anos.
# 2. crie uma lista das colunas desse *DataFrame* com o atributo de *DataFrame* **.columns()**
# 3. Nesse *DataFrame* faça uma contagem do campo ```vacina_categoria_nome```.
# 3. a partir da lista de colunas, escolha somente aquelas que são referentes ao estabelecimento, faça uma lista com esses valores.
# 4. usando o método *.loc*, selecione somente essas variáveis
# 5. Aplique o método **.drop_duplicates** e crie uma lista com uma linha para cada estabelecimento, com os dados do estabelecimento

# %%
# 1) 
vacAcre_copy = vacAcre[vacAcre['paciente_idade'] < 18].copy()
vacAcre_copy.head(5)
# Out:
#                                   document_id  \
# 0   4e15de2c-8226-4208-a510-a49398d202e9-i0b0
# 3   30eb23e8-b6f1-49ff-8c0a-009ae8ca0f73-i0b0
# 7   3136aa1d-026f-43bf-8eb0-ef8ab901e889-i0b0
# 20  ead404ab-64e4-42be-8590-1197cc0089ca-i0b0
# 23  32a9033b-eb65-429f-a096-4fb2f368635a-i0b0
#
#                                           paciente_id  paciente_idade  \
# 0   1cdfdf4bc68e515dcc74fe99bcbc7ee26eef857164df11...              15
# 3   ab032b6adc389b3f72849b3ce3ab71bd193558ca078ed4...              17
# 7   1cafeccc5a4c7e529ac3e37dc41df5754c1066e7ab17ce...              13
# 20  53accc856f15dbe53a4bbe32a243fc6e3b771c10190e55...              14
# 23  c0345bb774e3a0ce318db0dcb58141fc9e2867df67de51...              12
#
#    paciente_dataNascimento paciente_enumSexoBiologico  \
# 0               2006-06-22                          F
# 3               2004-03-15                          F
# 7               2008-06-23                          F
# ...

# %%
# 2) crie uma lista das colunas desse DataFrame com o atributo de DataFrame .columns()
lista_colunas = list(vacAcre_copy.columns)
lista_colunas
# Out:
# ['document_id',
#  'paciente_id',
#  'paciente_idade',
#  'paciente_dataNascimento',
#  'paciente_enumSexoBiologico',
#  'paciente_racaCor_codigo',
#  'paciente_racaCor_valor',
#  'paciente_endereco_coIbgeMunicipio',
#  'paciente_endereco_coPais',
#  'paciente_endereco_nmMunicipio',
#  'paciente_endereco_nmPais',
#  'paciente_endereco_uf',
#  'paciente_endereco_cep',
#  'paciente_nacionalidade_enumNacionalidade',
#  'estabelecimento_valor',
#  'estabelecimento_razaoSocial',
#  'estalecimento_noFantasia',
#  'estabelecimento_municipio_codigo',
#  'estabelecimento_municipio_nome',
#  'estabelecimento_uf',
#  'vacina_grupoAtendimento_codigo',
#  'vacina_grupoAtendimento_nome',
#  'vacina_categoria_codigo',
#  'vacina_categoria_nome',
#  'vacina_lote',
#  'vacina_fabricante_nome',
#  'vacina_fabricante_referencia',
#  'vacina_dataAplicacao',
#  'vacina_descricao_dose',
#  'vacina_codigo',
#  'vacina_nome',
#  'sistema_origem']

# %%
# 3) Nesse DataFrame faça uma contagem do campo vacina_categoria_nome.
vacAcre_copy['vacina_categoria_nome'].value_counts()
# Out:
# Faixa Etária                                      44115
# Outros                                             5441
# Povos Indígenas                                     926
# Povos e Comunidades Tradicionais                    259
# Trabalhadores de Saúde                              186
# População Privada de Liberdade                       65
# Comorbidades                                         31
# Gestantes                                            23
# Pessoas com Deficiência                               4
# Puérperas                                             3
# Trabalhadores Industriais                             1
# Trabalhadores da Educação                             1
# Pessoas de 60 anos ou mais institucionalizadas        1
# Name: vacina_categoria_nome, dtype: int64

# %%
# 4) a partir da lista de colunas, escolha somente aquelas que são referentes ao estabelecimento, 
#    faça uma lista com esses valores

lista_estabelecimento = []
for i in lista_colunas:
    # Achei um erro de digitacao em uma coluna
    if 'esta' in i and 'cimento' in i:
        lista_estabelecimento.append(i)
lista_estabelecimento
# Out:
# ['estabelecimento_valor',
#  'estabelecimento_razaoSocial',
#  'estalecimento_noFantasia',
#  'estabelecimento_municipio_codigo',
#  'estabelecimento_municipio_nome',
#  'estabelecimento_uf']

# %%
# 5)usando o método .loc, selecione somente essas variáveis
vacAcre_copy.loc[vacAcre_copy['paciente_idade'] < 18, lista_estabelecimento]
# Out:
#         estabelecimento_valor              estabelecimento_razaoSocial  \
# 0                     3541592   PREFEITURA MUNICIPAL DE SENA MADUREIRA
# 3                     3544915            PREFEITURA MUNICIPAL DE FEIJO
# 7                     2000571  PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL
# 20                    2002876             SECRETARIA MUNCIPAL DE SAUDE
# 23                    6159087  PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL
# ...                       ...                                      ...
# 463924                6917291       PREFEITURA MUNICIPAL DE RIO BRANCO
# 463926                5354072           PREFEITURA MUNICIPAL DE JORDAO
# 463930                6159087  PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL
# 463934                6917291       PREFEITURA MUNICIPAL DE RIO BRANCO
# 463946                5354072           PREFEITURA MUNICIPAL DE JORDAO
#
#                                  estalecimento_noFantasia  \
# ...

# %%
# 6) Aplique o método .drop_duplicates e crie uma lista com uma linha para cada estabelecimento, 
#    com os dados do estabelecimento

## Separei ainda mais alguns valores,
#  pois estabelecimento_municipio_codigo e estabelecimento_municipio_nome seriam redundantes

lista_estabelecimento_selecionados = ['estabelecimento_razaoSocial',
                                      'estalecimento_noFantasia',
                                      'estabelecimento_municipio_nome',
                                      'estabelecimento_uf']

vacAcre_copy.loc[vacAcre_copy['paciente_idade'] < 18, lista_estabelecimento_selecionados].drop_duplicates()
# Out:
#                    estabelecimento_razaoSocial  \
# 0       PREFEITURA MUNICIPAL DE SENA MADUREIRA
# 3                PREFEITURA MUNICIPAL DE FEIJO
# 7      PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL
# 20                SECRETARIA MUNCIPAL DE SAUDE
# 23     PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL
# ...                                        ...
# 18570  PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL
# 30488                 MUNICIPIO DE MANCIO LIMA
# 31919                      MINISTERIO DA SAUDE
# 80491           PREFEITURA MUNICIPAL DE JORDAO
# 98957            SECRETARIA DE ESTADO DE SAUDE
#
#                                 estalecimento_noFantasia  \
# 0       UNIDADE BASICA DE SAUDE MARIA DAS DORES DE PAULA
# 3      UNIDADE DE SAUDE DA FAMILIA DULCE DE ARAUJO AN...
# 7               UNIDADE DE SAUDE DA FAMILIA GERALDO MAIA
# 20      CENTRO DE SAUDE RAIMUNDA PORFIRIO DE BRITO RAMOS
# 23      SECRETARIA MUNICIPAL DE SAUDE DE CRUZEIRO DO SUL
# ...
