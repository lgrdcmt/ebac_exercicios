# %% [markdown]
# ## Árvores de regressão - exercícios 02
#
# Este exercício será uma continuação do anterior, mesma base, mesmas variáveis - vamos tentar buscar a 'melhor árvore'.
#
# A descrição das variáveis está abaixo:

# %% [markdown]
# | Variavel | Descrição|
# |-|-|
# |CRIM| taxa de crimes per-cápita da cidade |
# |ZN| proporção de terrenos residenciais zoneados para lotes com mais de 25.000 pés quadrados. |
# |INDUS| proporção de acres de negócios não varejistas por cidade |
# |CHAS |vale 1 se o terreno faz fronteira com o *Charles River*; 0 caso contrário |
# |NOX| Concentração de óxido nítrico (em partes por 10 milhões) |
# |RM| número médio de quartos por habitação |
# |AGE| proporção de unidades ocupadas pelo proprietário construídas antes de 1940 |
# |DIS| distâncias ponderadas até cinco centros de empregos de Boston |
# |RAD| índice de acessibilidade a rodovias radiais |
# |TAX| taxa de imposto sobre a propriedade de valor total por \\$10,000 |
# |PTRATIO| razão pupilo-professor da cidade |
# |B| $ 1000 (Bk - 0,63) ^ 2 $ onde Bk é a proporção de negros por cidade |
# |LSTAT| \%status inferior da população |
# |MEDV| (variável resposta) Valor mediano das casas ocupadas pelo proprietário em US $ 1.000|

# %%
import pandas as pd

import seaborn as sns

from sklearn import datasets
from sklearn.tree import DecisionTreeRegressor
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error


import matplotlib.pyplot as plt

# %%
boston = datasets.load_boston()
X = pd.DataFrame(boston.data, columns = boston.feature_names)
y = pd.DataFrame(boston.target, columns = ['MEDV'])
# Out:
# /usr/lib64/python3.10/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#         target = raw_df.values[1::2, 2]
#
#     Alternative datasets include the California housing dataset (i.e.
#     :func:`~sklearn.datasets.fetch_california_housing`) and the Ames housing
#     dataset. You can load the datasets as follows::
#
#         from sklearn.datasets import fetch_california_housing
#         housing = fetch_california_housing()
#
#     for the California housing dataset and::
#
#         from sklearn.datasets import fetch_openml
#         housing = fetch_openml(name="house_prices", as_frame=True)
#
#     for the Ames housing dataset.
#
#   warnings.warn(msg, category=FutureWarning)

# %%
X.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
y.head()
# Out:
#    MEDV
# 0  24.0
# 1  21.6
# 2  34.7
# 3  33.4
# 4  36.2

# %% [markdown]
# ### 1. Execute os passos do exercício anterior, até que você tenha uma árvore de regressão predizendo o valor do imóvel na base de treinamento.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 2360873)

# %%
regr_1 = DecisionTreeRegressor(max_depth = 8)
regr_2 = DecisionTreeRegressor(max_depth = 2)

regr_1.fit(X_train, y_train)
regr_2.fit(X_train, y_train)

mse_1 = regr_1.score(X_train, y_train)
mse_2 = regr_2.score(X_train, y_train)

template = 'O R-quadrado da árvore com profundidade = {0} é: {1:.2f}'

print(template.format(regr_1.get_depth(),mse_1).replace(".",","))
print(template.format(regr_2.get_depth(),mse_2).replace(".",","))

mse_1 = mean_squared_error(y_test, regr_1.predict(X_test))
mse_2 = mean_squared_error(y_test, regr_2.predict(X_test))

template = 'O MSE da árvore com profundidade = {0} é: {1:.2f}'

print(template.format(regr_1.get_depth(),mse_1).replace(".",","))
print(template.format(regr_2.get_depth(),mse_2).replace(".",","))
# Out:
# O R-quadrado da árvore com profundidade = 8 é: 0,98
# O R-quadrado da árvore com profundidade = 2 é: 0,71
# O MSE da árvore com profundidade = 8 é: 14,64
# O MSE da árvore com profundidade = 2 é: 26,46

# %% [markdown]
# ### 2.  Calcule o caminho indicado pelos CCP-alfas dessa árvore.

# %%
path = regr_1.cost_complexity_pruning_path(X_train, y_train)

path
# Out:
# {'ccp_alphas': array([0.00000000e+00, 2.39972217e-15, 1.31926121e-05, 1.18733509e-04,
#         2.11081794e-04, 3.29815303e-04, 3.29815303e-04, 3.29815303e-04,
#         5.32102023e-04, 6.46437995e-04, 7.43183817e-04, 8.44327177e-04,
#         8.61917326e-04, 1.31926121e-03, 1.31926121e-03, 1.59630607e-03,
#         1.93931398e-03, 1.94283201e-03, 2.54177661e-03, 2.58575198e-03,
#         2.58575198e-03, 2.96833773e-03, 3.37730871e-03, 3.44766931e-03,
#         3.74010554e-03, 4.76253298e-03, 5.57387863e-03, 6.05892700e-03,
#         6.35004398e-03, 7.14379947e-03, 7.39226033e-03, 7.44415128e-03,
#         9.04636261e-03, 9.69656992e-03, 1.43667546e-02, 1.48636763e-02,
#         1.59630607e-02, 1.61609499e-02, 1.74854881e-02, 1.80123131e-02,
#         1.82438120e-02, 1.85795954e-02, 1.90501319e-02, 1.90501319e-02,
#         2.11081794e-02, 2.11081794e-02, 2.17733069e-02, 2.20903694e-02,
#         2.43500021e-02, 2.64127089e-02, 2.80512627e-02, 3.83189471e-02,
#         4.02249026e-02, 4.84828496e-02, 5.56300046e-02, 5.74670185e-02,
#         5.76528144e-02, 6.43843448e-02, 6.43966998e-02, 6.80456245e-02,
#         7.04982010e-02, 7.29957383e-02, 7.34573439e-02, 7.86166382e-02,
#         8.69923043e-02, 8.80846597e-02, 9.00615655e-02, 9.56285052e-02,
#         1.06391821e-01, 1.07315743e-01, 1.08039463e-01, 1.17556069e-01,
#         1.20836868e-01, 1.23806069e-01, 1.25889423e-01, 1.41876765e-01,
#         1.49256931e-01, 1.53028093e-01, 1.70434946e-01, 1.81815743e-01,
#         2.61724644e-01, 3.16622691e-01, 3.29034741e-01, 3.78556601e-01,
#         4.43611535e-01, 5.02500496e-01, 5.47321975e-01, 5.48668376e-01,
#         5.65970286e-01, 6.61912674e-01, 7.29228881e-01, 7.40135415e-01,
#         8.76702946e-01, 9.66510554e-01, 1.55245502e+00, 2.78056299e+00,
#         3.05710520e+00, 4.66113142e+00, 5.28170375e+00, 1.70606107e+01,
#         4.16718568e+01]),
#  'impurities': array([ 1.80055536,  1.80055536,  1.80056855,  1.80068729,  1.80089837,
#          1.80122818,  1.801558  ,  1.80188781,  1.80241992,  1.80306635,
#          1.80380954,  1.80465386,  1.80551578,  1.80683504,  1.8081543 ,
#          1.80975061,  1.81168992,  1.81363276,  1.81617453,  1.81876029,
#          1.82134604,  1.82431437,  1.82769168,  1.83113935,  1.83861956,
#          1.8433821 ,  1.84895598,  1.8550149 ,  1.86136495,  1.86850875,
#          1.87590101,  1.88334516,  1.89239152,  1.90208809,  1.91645484,
#          1.93131852,  1.94728158,  1.96344253,  1.98092802,  1.99894033,
#          2.01718414,  2.03576374,  2.05481387,  2.073864  ,  2.09497218,
#          2.11608036,  2.15962698,  2.18171735,  2.20606735,  2.23248006,
#          2.26053132,  2.29885027,  2.37930007,  2.42778292,  2.53904293,
#          2.59650995,  2.65416276,  2.71854711,  2.78294381,  2.91903506,
#          2.98953326,  3.13552473,  3.20898208,  3.28759872,  3.37459102,
#          3.46267568,  3.55273725,  3.64836575,  3.75475757,  3.86207332,
#          3.97011278,  4.08766885,  4.20850572,  4.33231178,  4.58409063,
#          4.7259674 ,  4.87522433,  5.02825242,  5.36912231,  5.55093806,
#          5.8126627 ,  6.12928539,  6.45832013,  7.21543333,  7.65904487,
#          8.16154536,  8.70886734,  9.25753572,  9.823506  , 10.48541868,
#         11.21464756, 11.95478297, 12.83148592, 13.79799647, 15.35045149,
#         18.13101449, 21.18811969, 25.84925111, 31.13095486, 48.19156561,
#         89.86342242])}

# %%
ccp_alphas, impurities = path.ccp_alphas, path.impurities

plt.figure(figsize = (10, 6))
plt.plot(ccp_alphas, impurities)
plt.xlabel("Alpha efetivo")
plt.ylabel("Impureza total das folhas")
# Out:
# Text(0, 0.5, 'Impureza total das folhas')

# %% [markdown]
# ### 3. Para cada valor de alpha obtido no item 2, treine uma árvore com o respectivo alfa, e guarde essa árvore em uma lista.

# %%
clfs = []

for ccp_alpha in ccp_alphas:
    clf = DecisionTreeRegressor(random_state = 0, ccp_alpha = ccp_alpha)
    clf.fit(X_train, y_train)
    clfs.append(clf)

# %%
clfs
# Out:
# [DecisionTreeRegressor(random_state=0),
#  DecisionTreeRegressor(ccp_alpha=2.3997221682663013e-15, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=1.3192612137191168e-05, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.00011873350923682026, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.00021108179419685846, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.00032981530342992914, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.00032981530343007914, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.0003298153034302666, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.0005321020228665604, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.0006464379947226672, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.0007431838170620691, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.0008443271767814345, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.0008619173262994893, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.0013192612137209166, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.0013192612137228662, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.0015963060686015936, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.0019393139841675142, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.001942832014067323, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.0025417766051004814, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.002585751978891831, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.0025857519788924687, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.002968337730870712, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.0033773087071234885, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.0034476693051982573, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.0037401055408971453, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.004762532981530511, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.005573878627943771, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.006058927000880416, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.006350043975373939, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.007143799472295616, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.007392260334214818, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.007444151275286914, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.009046362608364628, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.009696569920837457, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.01436675461741348, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.01486367634124678, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.01596306068601631, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.016160949868073878, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.0174854881266485, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.018012313104663006, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.01824381203668831, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.018579595426559528, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.019050131926121445, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.019050131926122305, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.021108179419526564, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.021108179419534665, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.02177330694811025, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.022090369393136564, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.024350002094074397, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.026412708883026458, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.028051262721448016, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.038318947103902254, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.04022490262595702, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.04848284960422433, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.055630004588732226, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.05746701846965752, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.05765281442392499, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.06438434476693226, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.06439669975290986, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.0680456244503051, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.07049820100743759, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.0729957382689381, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.07345734388742661, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.0786166382120056, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.08699230430957056, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.08808465968742385, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.09006156552331232, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.09562850517995447, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.10639182058047911, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.10731574318381648, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.10803946311804807, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.11755606860158291, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.12083686789535109, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.12380606860160252, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.1258894234914808, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.14187676548191722, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.14925693090129777, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.15302809250350718, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.17043494649207747, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.1818157431838211, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.2617246437434717, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.316622691292876, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.3290347405452975, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.37855660138016056, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.44361153481670024, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.5025004958925398, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.5473219745533804, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.548668376372813, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.5659702862753697, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.6619126740763277, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.7292288812544625, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.7401354154715976, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.8767029463500755, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.9665105540897083, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=1.5524550208405028, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=2.7805629928629454, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=3.05710519999864, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=4.66113142066631, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=5.281703754062145, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=17.06061074970853, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=41.671856809753706, random_state=0)]

# %% [markdown]
# ### 4. Para cada árvore na lista, calcule o MSE da árvore.

# %%
tree_depths = [clf.tree_.max_depth for clf in clfs]

plt.figure(figsize = (10, 6))
plt.plot(ccp_alphas[ : -1], tree_depths[ : -1])
plt.xlabel('effective alpha')
plt.ylabel('Profundidade de árvore')
# Out:
# Text(0, 0.5, 'Profundidade de árvore')

# %% [markdown]
# ### 5. Monte um gráfico do MSE pelo alpha, escolha um valor de alpha perto do ponto de mínimo do MSE

# %%
train_scores = [mean_squared_error(y_train , clf.predict(X_train)) for clf in clfs]
test_scores  = [mean_squared_error(y_test  , clf.predict(X_test )) for clf in clfs]

fig, ax = plt.subplots()
ax.set_xlabel("alpha")
ax.set_ylabel("MSE")
ax.set_title("MSE x alpha do conjunto de dados de treino e teste")
ax.plot(ccp_alphas[:-1], train_scores[:-1], marker='o', label="treino",
        drawstyle="steps-post")
ax.plot(ccp_alphas[:-1], test_scores[:-1], marker='o', label="teste",
        drawstyle="steps-post")
ax.legend()
plt.show()

# %% [markdown]
# ### 6. Calcule o R-quadrado dessa árvore encontrada no item acima

# %%
arvore_final = DecisionTreeRegressor(random_state = 0, ccp_alpha = 2.5)
arvore_final.fit(X_train, y_train)

print(f"Profundidade: {arvore_final.tree_.max_depth}")
print(f"R-quadrado na base de testes: {arvore_final.score(X_test, y_test):.2f}")
print(f"MSE na base de testes: {mean_squared_error(y_test, arvore_final.predict(X_test)):.2f}")
# Out:
# Profundidade: 4
# R-quadrado na base de testes: 0.67
# MSE na base de testes: 22.70

# %% [markdown]
# ### 7. Visualize esta árvore.

# %%
plt.rc('figure', figsize = (15, 15))
tp = tree.plot_tree(arvore_final,
                   feature_names = X.columns,
                   filled = True)
